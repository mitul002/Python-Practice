# %%
#RECURSIVE

def fact(n):
 if n==1:
  return 1

 else:
  return n*fact(n-1)


fact(5)
# Out:
# 120

# %%
#ITERATIVE

def fact(n):
  fact=1
  for i in range(1, n+1, 1):
    fact=fact*i
  print(fact)


fact(5)
fact(10)
# Out:
# 120
# 3628800
