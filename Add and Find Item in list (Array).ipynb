# %%
#Find Item (if exists or not) in List

fruits=["Apple","Mango","Jackfruit", "Banana","Berry","Guava","Orange"]

print("Apple" in fruits)
print("apple" in fruits)

print("Lichi" in fruits)
# Out:
# True
# False
# False

# %%
#Add Items in List

fruits=["Mango","Jackfruit","Lichi"]
print(fruits,"\n")
print(fruits + ["Apple","Orange", "Strawberry"] ,"\n")

print(fruits +[10, 20, 30, 40, 50])
# Out:
# ['Mango', 'Jackfruit', 'Lichi']
#
# ['Mango', 'Jackfruit', 'Lichi', 'Apple', 'Orange', 'Strawberry']
#
# ['Mango', 'Jackfruit', 'Lichi', 10, 20, 30, 40, 50]
