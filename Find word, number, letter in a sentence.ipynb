# %%
word=0
letter=0
number=0

text=input("Enter Anything: ")

for i in text:
  i = i.lower()
  if i==" ":
    word=word+1

  elif 'a'<=i<='z':
    letter=letter+1

  elif '0' <= i <='9':
    number=number+1

print(letter)
print(word+1)
print(number)
# Out:
# Enter Anything: hello world 123
# 10
# 3
# 3
