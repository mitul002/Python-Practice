# %%
lis = []

for i in range(1,5+1,1):
  y=int(input())
  x= lis.append(y)

sum=0
for i in lis:
  sum=sum+int(lis[i])
print(f"Sum of this list is :",sum)
# Out:
# 4
# 5
# 3
# 4
# 5
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-04ee06358496> in <cell line: 8>()
#       7 sum=0
#       8 for i in lis:
# ----> 9   sum=sum+int(lis[i])
#      10 print(f"Sum of this list is :",sum)
#
# IndexError: list index out of range

# %%
n=input("Enter Numbers: ")
list=n.split()
sum=0

for num in list:
  sum=sum+int(num)
print(sum)
# Out:
# Enter Numbers: 5 3 3 3 44
# 58
