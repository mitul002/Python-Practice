# %%
result = input("Enter your result (number): ")

if(32<int(result)<=100):
  print("pass")

elif(int(result)<33):
    print("Fail")

elif(int(result)>100):
    print("Invalid")
# Out:
# Enter your result (number): 103
# Invalid
