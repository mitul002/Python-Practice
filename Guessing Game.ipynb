# %%
import random

while 1:


  num=int(input("Enter a number between 1-10: "))

  r=random.randint(1,10)

  if r==num:
    print("Win")
  else:
   print("lose")

  print("Right ans is: ", r)
# Out:
# lose
# Right ans is:  8
# lose
# Right ans is:  8
# lose
# Right ans is:  7
