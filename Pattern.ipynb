# %%
x=int(input())
for i in range(x+1):
  print(i*"*")
# Out:
# 5
#
# *
# **
# ***
# ****
# *****

# %%
x=int(input())
for i in range(1,x+1,2):
  print(i*"*")
# Out:
# 6
# *
# ***
# *****

# %%
x=int(input())
for i in range(x+1):
  print((x-i)* " ",  i * "*")
# Out:
# 6
#
#       *
#      **
#     ***
#    ****
#   *****
#  ******

# %%
x=int(input())

for i in range(x+1):
  print((x-i)* " ",  i * "*",  end="")
  print(i*"*")
# Out:
# 5
#
#      **
#     ****
#    ******
#   ********
#  **********

# %%
x=int(input())

for i in range(x+1):
  print((x-i)* " ",  i * "*",  end="")
  print(i*"*")


for i in range(x,0,-1):
  print((x-i)* " ",  i * "*")
# Out:
# 5
#
#      **
#     ****
#    ******
#   ********
#  **********
#  *****
#   ****
#    ***
#     **
#      *

# %%
x=int(input())

for i in range(x+1):
  print((x-i)* " ",  i * "*",  end="")
  print(i*"*")


for i in range(x,0,-1):
  print((x-i)* " ",  i * "*", end="")
  print(i*"*")
# Out:
# 5
#
#      **
#     ****
#    ******
#   ********
#  **********
#  **********
#   ********
#    ******
#     ****
#      **

# %%
x=int(input())

for i in range(x+1):
  print((x-i)* " ",  i * "*",  i*"*")



for i in range(x,0,-1):
  print((x-i)* " ",  i * "*", i*"*")
# Out:
# 6
#
#       * *
#      ** **
#     *** ***
#    **** ****
#   ***** *****
#  ****** ******
#  ****** ******
#   ***** *****
#    **** ****
#     *** ***
#      ** **
#       * *
