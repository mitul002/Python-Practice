# %%
'''
fOr string: +variable+
fOr int:    ,variable,
'''

name ="John"
age = 20
country = "Canada"
cgpa = 4.00

print("The boy named ",name," Lives in "+country)
print("He is", age ,"years old")
# Out:
# The boy named  John  Lives in Canada
# He is 20 years old
