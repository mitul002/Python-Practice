# %%
fruits = ["Apple","Mango","Jackfruit", "Banana"]
print(fruits[0])
print(fruits[1])
print(fruits[2])
print(fruits[3])

print("-------------")
print(fruits[-1])
print(fruits[-2])
# Out:
# Apple
# Mango
# Jackfruit
# Banana
# -------------
# Banana
# Jackfruit

# %%
fruits = ["Apple","Mango","Jackfruit", "Banana","Berry","Guava","Orange"]
print(fruits)
print(fruits[2:5]) #It will print index 2-4
print(fruits[2:])  #It will print index 2-last
print(fruits[:5])  #It will print index 0-4
# Out:
# ['Apple', 'Mango', 'Jackfruit', 'Banana', 'Berry', 'Guava', 'Orange']
# ['Jackfruit', 'Banana', 'Berry']
# ['Jackfruit', 'Banana', 'Berry', 'Guava', 'Orange']
# ['Apple', 'Mango', 'Jackfruit', 'Banana', 'Berry']
# Orange
