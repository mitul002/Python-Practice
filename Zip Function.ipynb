# %%
Name=["Mitul", "Sanjida", "Mahfuz" , "Piash" , "Sanju", "Alvi"]
ID =[4617, 4835, 4000, 5606, 5000, 5886]

result= list(zip(Name,ID))
print(result)
# Out:
# [('Mitul', 4617), ('Sanjida', 4835), ('Mahfuz', 4000), ('Piash', 5606), ('Sanju', 5000), ('Alvi', 5886)]

# %%
Name=["Mitul", "Sanjida", "Mahfuz" , "Piash" , "Sanju", "Alvi"]
ID =[4617, 4835, 4000, 5606, 5000, 5886]

result= list(zip(Name,ID, "DDKDOD"))
print(result)
# Out:
# [('Mitul', 4617, 'D'), ('Sanjida', 4835, 'D'), ('Mahfuz', 4000, 'K'), ('Piash', 5606, 'D'), ('Sanju', 5000, 'O'), ('Alvi', 5886, 'D')]
