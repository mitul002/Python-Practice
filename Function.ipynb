# %%
def sum(a,b):
  print(a+b)

def sub(a,b):
  return a-b

print("Addition of Numbers: ")
sum(100, 10)
sum(599, 77)
sum1 = sum(33, 66)
sum1 = sum(788, 25)


print("\n")
print("Subtraction of Numbers: ")

sub2 = sub(100, 10)
print(sub2)
sub2 = sub(1040, 180)
print(sub2)
sub2 = sub(670, 60)
print(sub2)
sub2 = sub(70, 60)
print(sub2)
# Out:
# Addition of Numbers:
# 110
# 676
# 99
# 813
#
#
# Subtraction of Numbers:
# 90
# 860
# 610
# 10
