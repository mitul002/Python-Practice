# %%
from math import *

print("Maximum: ",max(2,5))
print("Minimum: ",min(7,3))
print("Power: ",pow(7,2))
print("Absolute value: ",abs(-5))
print("Square root:", sqrt(36))
print("Ceiling: ",ceil(4.24))
print("Floor: ",floor(4.57))
print("Round: ",round(5.67))
# Out:
# Maximum:  5
# Minimum:  3
# Power:  49.0
# Absolute value:  5
# Square root: 6.0
# Ceiling:  5
# Floor:  4
# Round:  6
