# %%
#Range Function

a=list(range(10))
print(a)
# Out:
# range(0, 10)

# %%
b= list(range(5,10))
print(b)
# Out:
# [5, 6, 7, 8, 9]

# %%
#Find Odd Numbers by Range Function

odd=list(range(1,10,2))
print(odd)
# Out:
# [1, 3, 5, 7, 9]

# %%
#Find Even Numbers by Range Function

even=list(range(2,10,2))
print(even)
# Out:
# [2, 4, 6, 8]
