# %%
#Stack works in "last in first out method"
list1=[]

list1.append("Book 1")
list1.append("Book 2")
list1.append("Book 3")
list1.append("Book 4")

print(list1)
# Out:
# ['Book 1', 'Book 2', 'Book 3', 'Book 4']
# Now all books are:  ['Book 5', 'Book 6', 'Book 7']
# Now the top book is : Book 7

# %%
list2=['Book 5', 'Book 6', 'Book 7', 'Book 8']

list2.pop()
print("Now all books are: ",list2)
print("Now the top book is :",list2[-1])

list2.pop()
print("Now all books are: ",list2)
print("Now the top book is :",list2[-1])

list2.pop()
print("Now all books are: ",list2)
print("Now the top book is :",list2[-1])
# Out:
# Now all books are:  ['Book 5', 'Book 6', 'Book 7']
# Now the top book is : Book 7
# Now all books are:  ['Book 5', 'Book 6']
# Now the top book is : Book 6
# Now all books are:  ['Book 5']
# Now the top book is : Book 5
