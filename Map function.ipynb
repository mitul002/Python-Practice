# %%
def square(x):
  return x*x

num=[2,3,5,7]

result=list(map(square, num))
print(result)
# Out:
# [4, 9, 25, 49]

# %%
num=[2,3,5,7]
result=list(map(lambda a: a*a, num))
print(result)
# Out:
# [4, 9, 25, 49]
