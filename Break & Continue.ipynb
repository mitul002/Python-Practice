# %%
i=1
while i<=100:
  if i==10:
    break
  print(i)
  i+=1
print("Hello World")
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# Hello World

# %%
i=1
while i<=100:
  if i==10:
     continue
  print(i)
  i+=1
print("Hello World")
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
