# %%
sum=0
i=1
while i<101:
  sum=sum+i
  i=i+1
print(sum)
# Out:
# 5050

# %%
#odd
sum=0

i=1
while i<101:
  sum=sum+i
  i=i+2
print(sum)
# Out:
# 2500

# %%
#even
sum=0

i=0
while i<101:
  sum=sum+i
  i=i+2
print(sum)
# Out:
# 2550
