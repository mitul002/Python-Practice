# %%
#even number
last_no = input("Enter Range: ")

sum=0

for i in range(0, int(last_no) + 1, 2):
  sum = sum+i
print(sum)
# Out:
# Enter Range: 100
# 2550

# %%
#odd number
last_no = input("Enter Range: ")

sum=0

for i in range(1, int(last_no) + 1, 2):
  sum = sum+i
print(sum)
# Out:
# Enter Range: 100
# 2500
